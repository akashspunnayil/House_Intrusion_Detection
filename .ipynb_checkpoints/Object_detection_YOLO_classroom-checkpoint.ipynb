# %% [markdown]
# # 🎯👁️ Object Detection - Using YOLO

# %%
# pip install ultralytics

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
# 🔹 Load pre-trained YOLOv8 model
model = YOLO("yolov8n.pt")

# %%
# !ls '/media/akashs/FA22E72622E6E69B/DATA1_disk/ACADEMICS/3_IPCS_Works/data/yolo/'
# Out:
# classroom.jpg  face.jpg  ship.jpg  traffic.jpg

# %%
image_path = '/media/akashs/FA22E72622E6E69B/DATA1_disk/ACADEMICS/3_IPCS_Works/data/yolo/classroom.jpg'
img = cv2.imread(image_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
results = model(img_rgb)
# Out:
# /home/akashs/.local/lib/python3.8/site-packages/torch/cuda/__init__.py:128: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# 0: 448x640 10 persons, 3 chairs, 3 laptops, 193.6ms
# Speed: 6.2ms preprocess, 193.6ms inference, 2.9ms postprocess per image at shape (1, 3, 448, 640)

# %%
# 🔹 Extract results
boxes = results[0].boxes
names = model.names  # COCO class names

# %%
# 🔹 Draw results on the image
for box in boxes:
    x1, y1, x2, y2 = map(int, box.xyxy[0])  # bounding box
    conf = box.conf[0].item()
    cls = int(box.cls[0].item())
    label = f"{names[cls]}: {conf:.2f}"

    # Draw rectangle and label
    cv2.rectangle(img_rgb, (x1, y1), (x2, y2), (255, 0, 0), 2)
    cv2.putText(img_rgb, label, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX,
                0.6, (255, 0, 0), 2)

    print(f"🟢 Detected: {label} at ({x1}, {y1}, {x2}, {y2})")
# Out:
# 🟢 Detected: laptop: 0.92 at (358, 204, 520, 292)
# 🟢 Detected: person: 0.76 at (473, 112, 571, 250)
# 🟢 Detected: chair: 0.75 at (477, 315, 611, 404)
# 🟢 Detected: person: 0.71 at (17, 118, 235, 403)
# 🟢 Detected: laptop: 0.67 at (76, 178, 144, 230)
# 🟢 Detected: person: 0.65 at (335, 99, 448, 258)
# 🟢 Detected: person: 0.64 at (275, 33, 408, 269)
# 🟢 Detected: person: 0.55 at (205, 125, 381, 397)
# 🟢 Detected: person: 0.54 at (9, 110, 119, 229)
# 🟢 Detected: person: 0.43 at (106, 91, 138, 177)
# 🟢 Detected: chair: 0.40 at (571, 189, 611, 233)
# 🟢 Detected: laptop: 0.34 at (10, 178, 142, 246)
# 🟢 Detected: person: 0.32 at (21, 119, 344, 401)
# 🟢 Detected: chair: 0.31 at (316, 302, 451, 406)
# 🟢 Detected: person: 0.30 at (335, 100, 453, 397)
# 🟢 Detected: person: 0.25 at (471, 112, 574, 324)

# %%
# 🔹 Show final image
plt.figure(figsize=(20, 10))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("YOLOv8 Object Detection")
plt.show()
